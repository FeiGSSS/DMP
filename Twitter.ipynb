# %%
import pickle as pkl
with open("results/twitter_imm.pkl", "rb") as f:
    IMM_twitter_dmp_mc = pkl.load(f)

twitter_dmp = [item[0] for item in IMM_twitter_dmp_mc]

# %%
with open("results/lr_twitter_overlip2_0.5_mc.pkl", "rb") as f:
    DMP_3_4 = pkl.load(f)

# %%
with open("results/twitter_overlip0_MC1000.pkl", "rb") as f:
    twitter_overlip0 = pkl.load(f)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
x = range(1, 51, 2)
plt.plot(x, twitter_mc, marker="o", c="k")
plt.plot(x, DMP_3_4[1], marker="x")
plt.plot(x, twitter_overlip0, marker="X")
plt.plot(range(1, 51, 3), list(Twitter_overlap_Lr_1E_4_dmp_10_max.values()), marker="X")

plt.legend(["IMM","DMP_Overlap2", "DMP_Overlap0",
           "Twitter_overlap_Lr_1E_4_dmp_10_max"])

plt.xlabel("#Seeds")
plt.ylabel("Influence")
plt.xticks(x)
plt.yticks(range(0, 12000, 500))
plt.title("Twitter, n=81306, m=1768149")
plt.grid()

plt.savefig("DMP_vs_MC_Twitter.pdf")

# %% [markdown]
# # Combina Overlap

# %%
with open("results/twitter_imm.pkl", "rb") as f:
    IMM_twitter_dmp_mc = pkl.load(f)

twitter_dmp = [item[0] for item in IMM_twitter_dmp_mc]

# %%
with open("./results/Twitter_overlap_Lr_1E-4_dmp_10_max.pkl", "rb") as f:
    Twitter_overlap_Lr_1E_4_dmp_10_max = pkl.load(f)

# %%
with open("./results/Twitter_overlap_Lr_

# %%
with open("./results/Twitter_overlap_Lr_1E-05_dmp_10_max.pkl", "rb") as f:
    Twitter_overlap_Lr_1E_5_dmp_10_max = pkl.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-16343c546dde> in <module>
# ----> 1 with open("./results/Twitter_overlap_Lr_1E-05_dmp_10_max.pkl", "rb") as f:
#       2     Twitter_overlap_Lr_1E_5_dmp_10_max = pkl.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: './results/Twitter_overlap_Lr_1E-05_dmp_10_max.pkl'

# %%
plt.figure(figsize=(10,10))
x = range(1, 51, 2)
plt.plot(x, twitter_mc, marker="o", c="k")
plt.plot(range(1, 51, 3), list(Twitter_overlap_Lr_1E_4_dmp_10_max.values()), marker="X")

plt.legend(["IMM","Twitter_overlap_Lr_1E_4_dmp_10_max"])

plt.xlabel("#Seeds")
plt.ylabel("Influence")
plt.xticks(x)
plt.yticks(range(0, 12000, 500))
plt.title("Twitter, n=81306, m=1768149")
plt.grid()

plt.savefig("Twitter_Comb_overlap.pdf")
